# %% [markdown]
# <a href="https://colab.research.google.com/github/Ykkan7/Practika2/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torchvision.transforms as T
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open("Sample.png")

np_img = numpy.array(img)
t = T.ToTensor()(np_img)

Input = t.unsqueeze(0)
conv = nn.Conv2d(in_channels=3, out_channels=3, kernel_size=3,stride=2, bias=True)
output = conv(Input)


Out_img = output.squeeze(0)
Out_img = T.ToPILImage()(Out_img)
Out_img


Out_img.thumbnail((30, 30), Image.ANTIALIAS)

imgplot = plt.imshow(Out_img, interpolation ='sinc')
# Out:
# <ipython-input-29-42602b60a99d>:22: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   Out_img.thumbnail((30, 30), Image.ANTIALIAS)
